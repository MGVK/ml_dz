# %% [markdown]
# <div style="font-size:18pt; padding-top:20px; text-align:center">ЗАДАНИЕ. <b>Дескриптивный анализ данных</b> </div><hr>
# <div style="text-align:right;">Папулин С.Ю. <span style="font-style: italic;font-weight: bold;">(papulin.study@yandex.ru)</span></div>

# %% [markdown]
# <a name="0"></a>
# <div><span style="font-size:14pt; font-weight:bold">Содержание</span>
#     <ol>
#         <li><a href="#1">Варианты</a></li>
#         <li><a href="#2">Задание</a></li>
#     </ol>
# </div>

# %% [markdown]
# <p>Подключение стилей оформления</p>

# %%
# %%html
# <link href="css/style.css" rel="stylesheet" type="text/css">
# Out:
# <link href="css/style.css" rel="stylesheet" type="text/css">

# %% [markdown]
# <a name="1"></a>
# <div style="display:table; width:100%; padding-top:10px; padding-bottom:10px; border-bottom:1px solid lightgrey">
#     <div style="display:table-row">
#         <div style="display:table-cell; width:80%; font-size:14pt; font-weight:bold">1. Варианты</div>
#     	<div style="display:table-cell; width:20%; text-align:center; background-color:whitesmoke; border:1px solid lightgrey"><a href="#0">К содержанию</a></div>
#     </div>
# </div>

# %% [markdown]
# <p>Чтобы узнать свой вариант, введите Вашу фамилию в соответвующее поле ниже и запустите ячейку:</p>

# %%
surname = "Баяндин" #Ваша фамилия

alp = 'абвгдеёжзийклмнопрстуфхцчшщъыьэюя'
w = [1, 42, 21, 21, 34,  6, 44, 26, 18, 44, 38, 26, 14, 43,  4, 49, 45,
        7, 42, 29,  4,  9, 36, 34, 31, 29,  5, 30,  4, 19, 28, 25, 33]

d = dict(zip(alp, w))
variant =  sum([d[el] for el in surname.lower()]) % 40 + 1

print("Задача № 1, шаг 5 - вариант: ", variant % 5 + 1)
print("Задача № 1, шаг 11 - вариант: ", variant % 2 + 1 )
print("задача № 2 - вариант: ", variant % 4 + 1)
# Out:
# Задача № 1, шаг 5 - вариант:  4
# Задача № 1, шаг 11 - вариант:  2
# задача № 2 - вариант:  4

# %% [markdown]
# <div class="msg-block msg-warning">
#   <p class="msg-text-warn">Варианты могут не совпадать с последующими ДЗ</p>
# </div>

# %% [markdown]
# <a name="2"></a>
# <div style="display:table; width:100%; padding-top:10px; padding-bottom:10px; border-bottom:1px solid lightgrey">
#     <div style="display:table-row">
#         <div style="display:table-cell; width:80%; font-size:14pt; font-weight:bold">2. Задание</div>
#     	<div style="display:table-cell; width:20%; text-align:center; background-color:whitesmoke; border:1px solid lightgrey"><a href="#0">К содержанию</a></div>
#     </div>
# </div>

# %% [markdown]
# <div class="msg-block msg-imp">
#   <div class="msg-text-imp">
#       <p>СРОК СДАЧИ: до <b>-</b></p>
#       <p style="margin:0px">ПОСЛЕ СРОКА: первая неделя <b>-</b>, вторая неделя и далее до конца модуля <b>-</b>, потом <b>- баллов</b>
#       </p>
#   </div>
# </div>

# %% [markdown]
# <p><b>Задача 1.</b> Анализ индекса восприятия коррупции (Corruption Perceptions Index, CPI)</p>

# %% [markdown]
# <p>1. Подключите библиотеки numpy, pandas, matplotlib</p>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# <p>2. Загрузите данные из "data/Corruption_Perception_Index.csv" в DataFrame. Исходные данные и пояснения можно найти <a href="http://www.transparency.org/news/feature/corruption_perceptions_index_2016#table">здесь</a></p>

# %%
df = pd.read_csv("data/A1_Descriptive_Analysis/Corruption_Perception_Index.csv")

# %%
df
# Out:
#      2016 Rank        Country  2016 Score  2015 Score  2014 Score  2013 Score  \
# 0            1        Denmark          90        91.0        92.0        91.0
# 1            1    New Zealand          90        88.0        91.0        91.0
# 2            3        Finland          89        90.0        89.0        89.0
# 3            4         Sweden          88        89.0        87.0        89.0
# 4            5    Switzerland          86        86.0        86.0        85.0
# ..         ...            ...         ...         ...         ...         ...
# 171        170          Yemen          14        18.0        19.0        18.0
# 172        173          Syria          13        18.0        20.0        17.0
# 173        174  Korea (North)          12         8.0         8.0         8.0
# 174        175    South Sudan          11        15.0        15.0        14.0
# 175        176        Somalia          10         8.0         8.0         8.0
#
#      2012 Score                        Region
# 0          90.0       Europe and Central Asia
# 1          90.0                  Asia Pacific
# 2          90.0       Europe and Central Asia
# 3          88.0       Europe and Central Asia
# 4          86.0       Europe and Central Asia
# ..          ...                           ...
# 171        23.0  Middle East and North Africa
# 172        26.0  Middle East and North Africa
# 173         8.0                  Asia Pacific
# 174         NaN            Sub Saharan Africa
# 175         8.0            Sub Saharan Africa
#
# [176 rows x 8 columns]

# %% [markdown]
# <p>3. Отсортируйте данные по убыванию индекса DataFrame</p>

# %%
df.sort_values(by=["2016 Rank"],inplace=True,ascending=False)

# %% [markdown]
# <div><p>4. Отобразите данные по индексу CPI за 2016 год в виде горизонтального столбчатого графика. Примерный вид графика приведен ниже</p>
# <img src="img/cpi_2016_.png"></div>

# %%
plt.figure(figsize=(10,30))
plt.barh(df.Country,df["2016 Score"])
plt.grid()

# %% [markdown]
# <p>5. Сформируйте DataFrame из исходного для региона в соответствии с Вашим вариантом</p>
# <p><b>Вариант 4.</b> Middle East and North Africa</p>

# %%
meDF =df[df['Region'].isin(["Middle East and North Africa"])]

# %% [markdown]
# <p>6. Выведите данные DataFrame'a</p>

# %%
meDF
# Out:
#      2016 Rank               Country  2016 Score  2015 Score  2014 Score  \
# 172        173                 Syria          13        18.0        20.0
# 171        170                 Yemen          14        18.0        19.0
# 170        170                 Sudan          14        12.0        11.0
# 169        170                 Libya          14        16.0        18.0
# 165        166                  Iraq          17        16.0        16.0
# 142        142            Mauritania          27        31.0        30.0
# 137        136               Lebanon          28        28.0        27.0
# 130        131                  Iran          29        27.0        27.0
# 109        108                 Egypt          34        36.0        37.0
# 107        108               Algeria          34        36.0        36.0
# 92          90               Morocco          37        36.0        39.0
# 75          75                Kuwait          41        49.0        44.0
# 76          75               Tunisia          41        38.0        40.0
# 69          70               Bahrain          43        51.0        49.0
# 64          64                  Oman          45        45.0        45.0
# 62          62          Saudi Arabia          46        52.0        49.0
# 57          57                Jordan          48        53.0        49.0
# 31          31                 Qatar          61        71.0        69.0
# 27          28                Israel          64        61.0        60.0
# 25          24  United Arab Emirates          66        70.0        70.0
#
#      2013 Score  2012 Score                        Region
# 172        17.0        26.0  Middle East and North Africa
# 171        18.0        23.0  Middle East and North Africa
# 170        11.0        13.0  Middle East and North Africa
# 169        15.0        21.0  Middle East and North Africa
# 165        16.0        18.0  Middle East and North Africa
# 142        30.0        31.0  Middle East and North Africa
# 137        28.0        30.0  Middle East and North Africa
# 130        25.0        28.0  Middle East and North Africa
# 109        32.0        32.0  Middle East and North Africa
# 107        36.0        34.0  Middle East and North Africa
# 92         37.0        37.0  Middle East and North Africa
# 75         43.0        44.0  Middle East and North Africa
# 76         41.0        41.0  Middle East and North Africa
# 69         48.0        51.0  Middle East and North Africa
# 64         47.0        47.0  Middle East and North Africa
# 62         46.0        44.0  Middle East and North Africa
# 57         45.0        48.0  Middle East and North Africa
# 31         68.0        68.0  Middle East and North Africa
# 27         61.0        60.0  Middle East and North Africa
# 25         69.0        68.0  Middle East and North Africa

# %% [markdown]
# <div><p>7. Постройте графики индекса CPI за 2012-2016 для стран своего региона. Примерный вид графика приведен ниже</p>
# <img src="img/fig_springfield_region.png">
# </div>

# %%
cols_df = ["Country","2012 Score","2013 Score","2014 Score","2015 Score","2016 Score"]

plt.figure(figsize=(10,8))
plt.plot(["2012 Score","2013 Score","2014 Score","2015 Score","2016 Score"],
         meDF[cols_df[1:]].values.T,"o-"
        )
plt.grid()

plt.legend(meDF[cols_df[0]],loc = 'best')

# %%
meDF.columns
# Out:
# Index(['2016 Rank', 'Country', '2016 Score', '2015 Score', '2014 Score',
#        '2013 Score', '2012 Score', 'Region'],
#       dtype='object')

# %% [markdown]
# <p>8. Найдите страны с наибольшим и наименьшим значением CPI Вашего варианта региона за 2016 год</p>

# %%
print(meDF.loc[meDF["2016 Score"].idxmin(),"Country"] + "is lowest CPI at 2016")
meDF.loc[meDF["2016 Score"].idxmax(),"Country"] + "is lowest CPI at 2016"
# Out:
# Syriais lowest CPI at 2016
# 'United Arab Emiratesis lowest CPI at 2016'

# %% [markdown]
# <p>9. Определите средние значения за каждый год в период с 2012 по 2016</p>

# %%
meDF[cols_df[1:]].values.mean(axis= 0).tolist()
# Out:
# [38.2, 36.65, 37.75, 38.2, 35.8]

# %% [markdown]
# <div><p>10. Постройте графики индекса CPI за 2012-2016 для стран своего региона и выделите страны с наибольшим и наименьшим значением CPI за 2016 год, а также постройте графики для средних значение по региону и РФ. Примерный вид графика приведен ниже</p>
# <img src="img/fig_springfield_region_comb.png">
# </div>

# %%
cols_df = ["Country","2012 Score","2013 Score","2014 Score","2015 Score","2016 Score"]

x = ["2012 Score","2013 Score","2014 Score","2015 Score","2016 Score"]

plt.figure(figsize=(10,8))
plt.plot(x,  meDF[cols_df[1:]].values.T,"o--",alpha=0.2 )
plt.plot(x,meDF[cols_df[1:]].values.mean(axis= 0),"o-",label = "Mean")
plt.plot(x,meDF[cols_df[1:]].values.max(axis= 0),"o-",label = "Max")
plt.plot(x,meDF[cols_df[1:]].values.min(axis= 0),"o-",label = "Min")
plt.plot(x,df[df['Country']=="Russia"][cols_df[1:]].values.T,"o-",label = "Russia")
plt.grid()

plt.legend(loc = 'best')

# %% [markdown]
# <p>11. Определите как изменилось значение показателя в соответствии с Вашим вариантом с 2012 по 2016</p>
# <p><b>Вариант 2.</b> На сколько процентов значение CPI с 2012 по 2016</p>

# %% [markdown]
# <div class="msg-block msg-info">
#   <p class="msg-text-info">У нескольких стран может быть одна и та же позиция в рейтинге из-за одинаковых значений индекса</p>
# </div>

# %% [markdown]
# <p>12. Выведите </p>

# %%
import pandas as pnd

index = ["mean_2016", "max_2016", "min_2016", "Russia_2016"]
columns = ["Region", "Country", "Score 2012", "Score 2016", "Change in Position"]

# %%
columns = ["Region", "Country", "Score 2012", "Score 2016", "Change in Position"]
cities = ["Morocco","United Arab Emirates","Syria","Russia"]
from copy import copy
pdf = copy(df)
pdf.sort_values(by = "2012 Score",inplace = True)
pdf["2012 Rank"] = list(range(1,pdf.shape[0]+1))
pdf.sort_values(by = "2016 Score",inplace = True)
pdf["2016 Rank"] = list(range(1,pdf.shape[0]+1))
pdf["Change in Position"] = pdf["2016 Rank"]-pdf["2012 Rank"]
pdf = pdf[pdf["Country"].isin(cities)][["Region","Country","2012 Score","2016 Score","Change in Position"]]
pdf["Country"] = pnd.Categorical(pdf["Country"], cities)
pdf.sort_values("Country",inplace=True)
# pdf = pnd.DataFrame(index=index, columns=columns)
# pdf

# %%
pdf["change in %"] = pdf["2016 Score"]/pdf["2012 Score"]
pdf.drop("Change in Position",axis=1)
# columns = ["Region", "Country", "Score 2012", "Score 2016", "Change in %"]
# df_why = pnd.DataFrame(index=index, columns=columns)
# df_why
# Out:
#                            Region               Country  2012 Score  \
# 92   Middle East and North Africa               Morocco        37.0
# 25   Middle East and North Africa  United Arab Emirates        68.0
# 172  Middle East and North Africa                 Syria        26.0
# 133       Europe and Central Asia                Russia        28.0
#
#      2016 Score  change in %
# 92           37     1.000000
# 25           66     0.970588
# 172          13     0.500000
# 133          29     1.035714

# %%
# Ваш код

# %% [markdown]
# <p><b>Задача 2.</b> Анализ рынка акций</p>

# %% [markdown]
# <p>1. Загрузите данные в один dataframe из всех файлов в папке /data/stock. Все файлы имеют одинаковую структуру, в том числе наименование столбцов. В качестве значений индекса dataframe'а необходимо указать значения столбца "Date". Название столбцов должные соответствовать названию акций (имя файла без .csv), а их значения - значениям цены закрытия (столбец "Close" в файлах .csv)</p>

# %%
# Ваш код
import os
from os import getcwd
read = []
names = []
for i in os.listdir("data/A1_Descriptive_Analysis/stock"):
    dfStock = pnd.read_csv("data/A1_Descriptive_Analysis/stock/"+i, index_col=0, parse_dates=True)# - загрузка из файла в dataframe
    read.append(dfStock["Close"])
    names.append(i.replace(".csv",""))

df = pd.DataFrame(columns=names)

for series,name in zip(read,names):
    df[name] = series
df
# Out:
#                   NVDA       GOOGL        NTES        ADBE       EBAY  \
# Date
# 2017-02-01  101.480003  844.929993  305.059998  118.339996  33.900002
# 2017-01-03  109.180000  820.190002  253.899994  113.379997  31.830000
# 2016-12-01  106.739998  792.450012  215.339996  102.949997  29.690001
# 2016-11-01   92.199997  775.880005  224.100006  102.809998  27.809999
# 2016-10-03   71.160004  809.900024  256.989990  107.510002  28.510000
# 2016-09-01   68.519997  804.059998  240.779999  108.540001  32.900002
# 2015-08-03  35.000000   89.430000  43.520000  71.309998
# 2015-07-01        NaN   94.010002  46.700001  76.709999
# 2015-06-01        NaN   85.769997  44.150002  69.820000
# 2015-05-01        NaN   79.190002  46.860001  76.269997
# 2015-04-01        NaN   78.769997  48.639999  73.779999
# 2015-03-02        NaN   82.220001  40.660000  71.050003
#
# [24 rows x 23 columns]

# %% [markdown]
# <p>2. Рассчитайте корреляционную матрицу для всех акций</p>

# %%
df.corr()
# Out:
#            NVDA     GOOGL      NTES      ADBE      EBAY       SAP      INFY  \
# NVDA   1.000000  0.718214  0.888984  0.887010 -0.249428  0.823598 -0.509313
# GOOGL  0.718214  1.000000  0.766282  0.882737 -0.714192  0.814216 -0.736510
# NTES   0.888984  0.766282  1.000000  0.945812 -0.226171  0.886792 -0.547505
# ADBE   0.887010  0.882737  0.945812  1.000000 -0.438998  0.903788 -0.644775
# EBAY  -0.249428 -0.714192 -0.226171 -0.438998  1.000000 -0.217757  0.703138
# SAP    0.823598  0.814216  0.886792  0.903788 -0.217757  1.000000 -0.426234
# INFY  -0.509313 -0.736510 -0.547505 -0.644775  0.703138 -0.426234  1.000000
# CTSH  -0.667971 -0.457821 -0.665497 -0.639420  0.125003 -0.625570  0.361764
# INTU   0.833649  0.552273  0.860492  0.805904 -0.029323  0.806879 -0.324549
# CHKP   0.504884  0.317104  0.460174  0.472383  0.010033  0.430469 -0.083422
# YHOO   0.501245  0.030759  0.528069  0.394537  0.543315  0.542135  0.248663
# BIDU  -0.335238 -0.203350 -0.228890  0.032627 -0.190022 -0.055597  0.378583
# RHT    0.136339  0.184321  0.379601  0.295120  0.161196  0.301397 -0.029536
# BABA   0.699008  0.452358  0.806564  0.714708  0.198884  0.805775 -0.168569
# CRM    0.286524  0.490075  0.484870  0.534918 -0.264918  0.484253 -0.280892
# ADSK   0.892613  0.655533  0.880215  0.853387 -0.053116  0.874067 -0.322194
# TWTR  -0.571686 -0.835478 -0.575405 -0.744648  0.801031 -0.579325  0.755395
# VMW    0.271619 -0.308122  0.218694  0.007322  0.587035  0.031364  0.200759
# CA     0.517295  0.258513  0.525692  0.470015  0.176644  0.609354  0.085652
# PYPL   0.708027  0.756846  0.752939  0.815057  0.451863  0.819823 -0.566059
# FB     0.772486  0.924629  0.841936  0.945377 -0.591459  0.868264 -0.681509
# MSFT   0.873954  0.890728  0.884819  0.918658 -0.406572  0.919401 -0.596066
# AKAM  -0.054151 -0.567284 -0.169440 -0.351316  0.562100 -0.365017  0.377319
#
#            CTSH      INTU      CHKP  ...      BABA       CRM      ADSK  \
# NVDA  -0.667971  0.833649  0.504884  ...  0.699008  0.286524  0.892613
# GOOGL -0.457821  0.552273  0.317104  ...  0.452358  0.490075  0.655533
# NTES  -0.665497  0.860492  0.460174  ...  0.806564  0.484870  0.880215
# ADBE  -0.639420  0.805904  0.472383  ...  0.714708  0.534918  0.853387
# EBAY   0.125003 -0.029323  0.010033  ...  0.198884 -0.264918 -0.053116
# SAP   -0.625570  0.806879  0.430469  ...  0.805775  0.484253  0.874067
1.000000
#
# [23 rows x 23 columns]

# %% [markdown]
# <p>3. Отобразите корреляционную матрицу в виде диаграммы. Примерный вид графика приведен ниже</p>
# <img src="img/fig_corr_matrix.png" width="400px">

# %%
import seaborn as sn
plt.figure(figsize=(15,15))
sn.heatmap(df.corr(), annot=True)

plt.show()


# matshow(corrMatrix, vmin=-1, vmax=1)

# %% [markdown]
# <div>
# <p>4. В соответствии с Вашим вариантом определите:</p>
# <ul>
#     <li>акцию с максимальной корреляцией (max)</li>
#     <li>акцию с минимальной корреляцией (min) </li>
#     <li>акцию, которая больше всего соответствует отсутствию какой-либо корреляции (none)</li>
# </ul>
# </div>

# %% [markdown]
# <p><b>Вариант 4.</b> Alibaba (BABA)</p>

# %%
baba = df.corr()["BABA"].drop("BABA")

# %%
baba.idxmax()
# Out:
# 'ADSK'

# %%
baba.idxmin()
# Out:
# 'CTSH'

# %%
baba.abs().idxmin()
# Out:
# 'BIDU'

# %% [markdown]
# <p>5. Постройте диаграммы разброса (Ваша компания - Компания с min), (Ваша компания - Компания с max), (Ваша компания - Компания с none)</p>

# %%
# Ваш код
plt.figure(figsize=(10,10))
plt.plot(df.index,df["BABA"],"o-",label="BABA")
plt.plot(df.index,df["CTSH"],"o-",label="CTSH MIN")
plt.plot(df.index,df["ADSK"],"o-",label="ADSK MAX")
plt.plot(df.index,df["BIDU"],"o-",label="BIDU NONE")
plt.legend(loc="best")
plt.grid()

# %% [markdown]
# <p>6. Рассчитайте среднюю цену акций для каждого месяца (исходные данные взяты с интервалом в месяц)</p>

# %%
df.mean(axis=1)
# Out:
# Date
# 2017-02-01    122.210869
# 2017-01-03    117.401739
# 2016-12-01    109.423044
# 2016-11-01    109.284782
# 2016-10-03    112.875653
# 2016-09-01    111.394783
# 2016-08-01    107.825217
# 2016-07-01    105.233915
# 2016-06-01     98.156523
# 2016-05-02    101.787825
# 2016-04-01     96.432609
# 2016-03-01     95.410456
# 2016-02-01     88.829090
# 2016-01-04     91.659999
# 2015-12-01     97.331364
# 2015-11-02     97.221363
# 2015-10-01     94.246364
# 2015-09-01     83.863182
# 2015-08-03     84.474546
# 2015-07-01     92.813333
# 2015-06-01     87.711903
# 2015-05-01     90.564762
# 2015-04-01     89.109049
# 2015-03-02     88.030001
# dtype: float64

# %% [markdown]
# <p>7. Постройте графики для акций из пункта 4 и средней из пункта 6. Примерный вид графика приведен ниже</p>
# <img src="img/fig_tw_comp.png">

# %%
plt.figure(figsize=(10,10))
plt.plot(df.index,df["BABA"],"o-",label="BABA")
plt.plot(df.index,df.mean(axis=1),"o-",label="MEAN")

plt.plot(df.index,df["CTSH"],"o-",label="CTSH MIN")
plt.plot(df.index,df["ADSK"],"o-",label="ADSK MAX")
plt.plot(df.index,df["BIDU"],"o-",label="BIDU NONE")
plt.grid()

plt.legend(loc="best")
