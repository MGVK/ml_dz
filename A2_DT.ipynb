# %% [markdown]
# <div style="font-size:18pt; padding-top:20px; text-align:center">ЗАДАНИЕ. <b>Дерево решений </b></div><hr>
# <div style="text-align:right;">Папулин С.Ю. <span style="font-style: italic;font-weight: bold;">(papulin.study@yandex.ru)</span></div>

# %% [markdown]
# <a name="0"></a>
# <div><span style="font-size:14pt; font-weight:bold">Содержание</span>
#     <ol>
#         <li><a href="#1">Варианты</a></li>
#         <li><a href="#2">Задание</a></li>
#     </ol>
# </div>

# %% [markdown]
# Подключение стилей оформления

# %%
# %%html
# <link href="css/style.css" rel="stylesheet" type="text/css">
# Out:
# <link href="css/style.css" rel="stylesheet" type="text/css">

# %% [markdown]
# <a name="1"></a>
# <div style="display:table; width:100%; padding-top:10px; padding-bottom:10px; border-bottom:1px solid lightgrey">
#     <div style="display:table-row">
#         <div style="display:table-cell; width:80%; font-size:14pt; font-weight:bold">1. Варианты</div>
#     	<div style="display:table-cell; width:20%; text-align:center; background-color:whitesmoke; border:1px solid lightgrey"><a href="#0">К содержанию</a></div>
#     </div>
# </div>

# %% [markdown]
# <div class="msg-block msg-warning">
#   <p class="msg-text-warn">Варианты могут не совпадать с предыдущими ДЗ</p>
# </div>

# %% [markdown]
# <p>Чтобы узнать свой вариант, введите Вашу фамилию в соответвующее поле ниже и запустите ячейку:</p>

# %%
surname = "Баяндин" #Ваша фамилия

alp = 'абвгдеёжзийклмнопрстуфхцчшщъыьэюя'
w = [1, 42, 21, 21, 34,  6, 44, 26, 18, 44, 38, 26, 14, 43,  4, 49, 45,
        7, 42, 29,  4,  9, 36, 34, 31, 29,  5, 30,  4, 19, 28, 25, 33]

d = dict(zip(alp, w))
variant =  sum([d[el] for el in surname.lower()]) % 15 + 1
print("Ваш вариант - ", variant)

import itertools
comb = list(itertools.combinations(range(1, 7), 2))
print("Задача №", comb[variant-1][0])
print("Задача №", comb[variant-1][1])
# Out:
# Ваш вариант -  13
# Задача № 4
# Задача № 5

# %% [markdown]
# <a name="2"></a>
# <div style="display:table; width:100%; padding-top:10px; padding-bottom:10px; border-bottom:1px solid lightgrey">
#     <div style="display:table-row">
#         <div style="display:table-cell; width:80%; font-size:14pt; font-weight:bold">2. Задание</div>
#     	<div style="display:table-cell; width:20%; text-align:center; background-color:whitesmoke; border:1px solid lightgrey"><a href="#0">К содержанию</a></div>
#     </div>
# </div>

# %% [markdown]
# <ol>
#     <li>Загрузить исходные данные</li>
#     <li>Отобразить исходные данные</li>
#     <li>Разделить исходные данные на обучающее (train_init) и тестовое подмножества (test) - см. ДЗ 5-6</li>
#     <li>Разделить обучающее подмножество (train_init) на 4 folds - см. ДЗ 5-6</li>
#     <li>Выбрать модель: построить график MSE/Accuracy-Max_depth, выбрать наилучшую модель</li>
#     <li>Повторить обучение лучшей модели на train_init</li>
#     <li>Проверить на тестовом подмножестве</li>
#     <li>Построить итоговые графики регрессии/классификации для train_init и test</li>
# </ol>

# %% [markdown]
# <div class="msg-block msg-info">
#   <p class="msg-text-info">Везде random_state=0</p>
# </div>

# %% [markdown]
# <p><b>Задача 1.</b> Регрессия и Decision Tree - набор <b><i>"Reg_A5.csv"</i></b></p>

# %%
DecisionTreeRegressor(criterion="mse", max_depth=i, random_state=0)

# %% [markdown]
# <p><b>Задача 2.</b> Регрессия и Random Forest - набор <b><i>"Reg_A5.csv"</i></b></p>

# %%
RandomForestRegressor(n_estimators=50, max_depth=i, criterion="mse", bootstrap=True,
                                    oob_score=False, random_state=0)

# %% [markdown]
# <p><b>Задача 3.</b> Классификация и Decision Tree - набор <b><i>"Cl_A5_V1.csv"</i></b></p>

# %%
DecisionTreeClassifier(criterion="entropy", max_depth=i, random_state=0)

# %% [markdown]
# <p><b>Задача 4.</b> Классификация и Decision Tree - набор <b><i>"Cl_A5_V2.csv"</i></b></p>

# %%
DecisionTreeClassifier(criterion="entropy", max_depth=i, random_state=0)

# %%
import pandas as pd
from sklearn import tree,datasets
from sklearn.model_selection import train_test_split
from graphviz import Source
from IPython.display import SVG

# %%
df=pd.read_csv("data/A2_DT/Cl_A5_V1.csv")
df.plot.scatter(x=0,y=1,c=df['Y'].map(lambda x: 'red' if x==1 else 'yellow'))
# df['Y'].map(lambda x: 'red' if x==1 else 'yellow')

# %%
# x_train, x_test, y_train, y_test = train_test_split(df[["X1","X2"]], df["Y"], test_size=0.6, random_state=0)

# %%
pd.DataFrame(d[0]).plot.scatter(x=0,y=1,c=pd.Series(d[1]).map(lambda x: 'red' if x else 'yellow'))

# %%
decTree = tree.DecisionTreeClassifier(criterion="entropy")
decTree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
d = datasets.make_circles(1000,noise=0.1)
pd.DataFrame(d[0]).plot.scatter(x=0,y=1,c=pd.Series(d[1]).map(lambda x: 'red' if x else 'yellow'))
x_test2=list()
for i in range(-150,150,1):
    for j in range(-150,150,1):
        x_test2.append([i/100.0,j/100.0])


# for r in range(5,100,5):
# x_train, x_test, y_train, y_test = train_test_split(d[0], d[1], test_size=r/100.0, shuffle=True)
x_train, x_test, y_train, y_test = train_test_split(d[0], d[1], test_size=0.1, shuffle=True)
decTree2 = tree.DecisionTreeClassifier(criterion="gini")
decTree2.fit(x_train,y_train)
print(r/100.0)
pd.DataFrame(x_test2).plot.scatter(x=0,y=1,
                                   c=pd.Series(decTree2.predict(x_test2)).map(lambda x: 'red' if x else 'yellow'))

# graph = Source( tree.export_graphviz(decTree2, out_file=None, feature_names=["X1","X2"]))
# SVG(graph.pipe(format='svg'))
# Out:
# 0.95

# %%
graph = Source( tree.export_graphviz(decTree2, out_file=None, feature_names=["X1","X2"]))
SVG(graph.pipe(format='svg'))

# %%
decTree.score(x_test,y_test)
# Out:
# 0.9333333333333333

# %%
result=list([])
for i in [x/100 for x in range(1,100,1)]:
    sum=0
    for j in range(0,10):
        x_train, x_test, y_train, y_test = train_test_split(d[0], d[1], test_size=i,shuffle=True)
        decTree = tree.DecisionTreeClassifier(criterion="entropy")
        decTree.fit(x_train,y_train)
        sum+=decTree.score(x_test,y_test);
    result.append([i,sum/10.0])

result
# Out:
# [[0.01, 1.0],
#  [0.02, 1.0],
#  [0.03, 1.0],
#  [0.04, 0.975],
#  [0.05, 0.9400000000000001],
#  [0.06, 0.9166666666666666],
#  [0.07, 0.9625],
#  [0.08, 0.975],
#  [0.09, 0.9111111111111111],
#  [0.1, 0.97],
#  [0.11, 0.9363636363636363],
#  [0.12, 0.95],
#  [0.13, 0.976923076923077],
#  [0.14, 0.8733333333333333],
#  [0.15, 0.9600000000000002],
#  [0.16, 0.925],
#  [0.17, 0.9000000000000001],
#  [0.18, 0.9388888888888889],
#  [0.19, 0.9263157894736841],
#  [0.2, 0.9200000000000002],
#  [0.21, 0.9571428571428571],
#  [0.22, 0.9318181818181819],
#  [0.23, 0.9521739130434783],
#  [0.24, 0.9083333333333332],
#  [0.25, 0.96],
#  [0.26, 0.9615384615384617],
#  [0.27, 0.9185185185185183],
#  [0.28, 0.8758620689655172],
#  [0.29, 0.9068965517241379],
#  [0.3, 0.9333333333333333],
#  [0.31, 0.9129032258064516],
#  [0.32, 0.928125],
#  [0.33, 0.9090909090909092],
#  [0.34, 0.876470588235294],
#  [0.35, 0.8914285714285715],
#  [0.36, 0.8555555555555555],
#  [0.37, 0.8837837837837836],
# ...

# %%
= 0.495 samples = 804 value = [363, 441]df_res = pd.DataFrame(result)
df_res.plot(x=0,y=1)

# %% [markdown]
# <p><b>Задача 5.</b> Классификация и Random Forest - набор <b><i>"Cl_A5_V1.csv"</i></b></p>

# %%
d = datasets.make_circles(1000,noise=0)
x_test2=list()
for i in range(-150,150,1):
    for j in range(-150,150,1):
        x_test2.append([i/100.0,j/100.0])
        
pd.DataFrame(d[0]).plot.scatter(x=0,y=1,c=pd.Series(d[1]).map(lambda x: 'red' if x else 'yellow'))

x_train, x_test, y_train, y_test = train_test_split(d[0], d[1], test_size=0.1, shuffle=True)



decTree2 = ensemble.RandomForestClassifier(n_estimators=10,n_jobs=8, criterion="entropy", 
                                           bootstrap=True, oob_score=False)
decTree2.fit(x_train,y_train)
# print(r/100.0)
predict_data=decTree2.predict(x_test2)
pd.DataFrame(x_test2).plot.scatter(x=0,y=1,
                                   c=pd.Series(decTree2.predict(x_test2)).map(lambda x: 'red' if x else 'yellow'))

print(accuracy_score(y_test,decTree2.predict(x_test)))
# Out:
# 1.0

# %% [markdown]
# <p><b>Задача 6.</b> Классификация и Random Forest - набор <b><i>"Cl_A5_V2.csv"</i></b></p>

# %%
RandomForestClassifier(n_estimators=50, max_depth=i, criterion="entropy", bootstrap=True, 
                                    oob_score=False, random_state=0)
